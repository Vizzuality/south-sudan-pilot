# %% [markdown]
# # South Sudan Data Precalculations
#
# This notebook is used to precalculate data at different regions of South Sudan.
#
# ## Data Hierarchy
#
# The data is organized in the following hierarchy:
#
# - [This](https://docs.google.com/spreadsheets/d/1RdJCjygAiWu2zBMGRF0ayigzrA2WhaObWMNdlkllgSQ/edit?usp=sharing) is the link to the data hierarchy spreadsheet.
#
# ## Data Access
# The data is stored in the following Google Cloud Storage bucket:
# - https://console.cloud.google.com/storage/browser/wbhydross_deliverables

# %% [markdown]
# ## Setup
#
# ### Library import

# %%
# imports
import json
import sys
from pprint import pprint

import pandas as pd
from dask.distributed import Client

# Include local library paths if you have ../src/utils.py
sys.path.append("../src/")
sys.path.append("../src/animations")
sys.path.append("../src/datasets")
sys.path.append("../src/helpers")
sys.path.append("../src/processing")
sys.path.append("../src/datasets/factory")

from datasets.datasets import dataset_database
from zonal_statistics import ZonalStatisticsParallel

# %% [markdown]
# **Start Dask Client for Dashboard**

# %%
client = Client()
client  # noqa: B018
# Out:
# <Client: 'tcp://127.0.0.1:45305' processes=4 threads=16, memory=14.98 GiB>

# %% [markdown]
# ### Utils

# %%
def print_dict(d):
    """
    Print a dictionary with indentation.
    """
    print(json.dumps(d, indent=2))

# %% [markdown]
# # Data Acquisition

# %% [markdown]
# ## Dataset information

# %%
datasets = dataset_database.datasets()
pprint(datasets)
# Out:
# {'Agricultural drought exposure': <datasets.datasets.Dataset object at 0x7f3b4d5bb980>,
#  'Agricultural drought hazard': <datasets.datasets.Dataset object at 0x7f3b4d5bb2c0>,
#  'Boundaries': <datasets.datasets.Dataset object at 0x7f3b4d5bac90>,
#  'Contextual layers': <datasets.datasets.Dataset object at 0x7f3b4d5bac60>,
#  'EO-based flood exposure': <datasets.datasets.Dataset object at 0x7f3b4d5bb800>,
#  'EO-based flood hazard': <datasets.datasets.Dataset object at 0x7f3b4d5bbc80>,
#  'Hydrographic data': <datasets.datasets.Dataset object at 0x7f3b4d5bbd10>,
#  'Hydrometeorological Data': <datasets.datasets.Dataset object at 0x7f3b4d5b8200>,
#  'Meteorological drought exposure': <datasets.datasets.Dataset object at 0x7f3b4d5ba300>,
#  'Meteorological drought hazard': <datasets.datasets.Dataset object at 0x7f3b4d5b8ce0>,
#  'Model-based flood exposure': <datasets.datasets.Dataset object at 0x7f3b4d5ba960>,
#  'Model-based flood hazard': <datasets.datasets.Dataset object at 0x7f3b4d5bb530>,
#  'Populated infrastructures': <datasets.datasets.Dataset object at 0x7f3b4d5bbbc0>,
#  'Transportation Network Infrastructures': <datasets.datasets.Dataset object at 0x7f3b4d5bbb90>,
#  'Water-related infrastructures': <datasets.datasets.Dataset object at 0x7f3b4d5ba360>}

# %% [markdown]
# ## Vector Data
# **Load the vector data**

# %%
dataset = datasets.get("Boundaries")
vector_layers = dataset.layers()
for layer_name, layer in vector_layers.items():
    print(layer_name)
    print_dict(layer.to_dict())
# Out:
# Administrative Boundaries - adm0
# {
#   "name": "Administrative Boundaries - adm0",
#   "type": "vector",
#   "format": "Shapefile",
#   "url": "https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm0_4326_SouthSudan_20230829_20240228.shp",
#   "styles": ""
# }
# Administrative Boundaries - adm1
# {
#   "name": "Administrative Boundaries - adm1",
#   "type": "vector",
#   "format": "Shapefile",
#   "url": "https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm1_4326_SouthSudan_20230829_20240228.shp",
#   "styles": ""
# }
# Administrative Boundaries - adm2
# {
#   "name": "Administrative Boundaries - adm2",
#   "type": "vector",
#   "format": "Shapefile",
#   "url": "https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm2_4326_SouthSudan_20230829_20240228.shp",
#   "styles": ""
# }
# Administrative Boundaries - adm3
# {
#   "name": "Administrative Boundaries - adm3",
#   "type": "vector",
#   "format": "Shapefile",
#   "url": "https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm3_4326_SouthSudan_20230829_20240228.shp",
#   "styles": ""
# }
# Hydrological Basins
# {
#   "name": "Hydrological Basins",
#   "type": "vector",
#   "format": "Shapefile",
#   "url": "https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/HydroSHEDS/HydroBasins/WBHYDROSSD_HydroBASINS-polys_4326_SouthSudan_2023_20240506.shp",
#   "styles": ""
# }

# %% [markdown]
# ## Raster Data
# **Load the raster data**

# %%
dataset = datasets.get("Hydrometeorological Data")
raster_layers = dataset.layers()
for layer_name, layer in raster_layers.items():
    print(layer_name)
    print_dict(layer.to_dict())
# Out:
# Precipitation
# {
#   "name": "Precipitation",
#   "type": "raster",
#   "format": "Zarr",
#   "url": "gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr",
#   "styles": "{'colors': ['#FFFFFF', '#67C3BF', '#211F4D'], 'vmin': 0, 'vmax': 500, 'time_coord': 'month'}"
# }
# Soil moisture
# {
#   "name": "Soil moisture",
#   "type": "raster",
#   "format": "Zarr",
#   "url": "gs://wbhydross_deliverables/D3-Database/03-Soil Moisture_hydrological_soil_properties/Soil Moisture-ERA5Land/WBHYDROSSD_ERA5-Land_mean-swvl1swvl2-M-mean_South_Sudan-EPSG4326_195001_202312_20240208154611.zarr",
#   "styles": "{'colors': ['#FFFFFF', '#AE55A7', '#211F4D'], 'vmin': 0, 'vmax': 0.5, 'time_coord': 'month'}"
# }
# Temperature
# {
#   "name": "Temperature",
#   "type": "raster",
#   "format": "Zarr",
#   "url": "gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Temperature-ERA5Land/WBHYDROSSD_ERA5-Land_t2m-D-mean_South_Sudan-EPSG4326_19500101_20231231_20240209091716.zarr",
#   "styles": "{'colors': ['#FFFFFF', '#E8eB5B', '#211F4D'], 'vmin': 10, 'vmax': 35, 'time_coord': 'month'}"
# }

# %% [markdown]
# # Zonal statistics
# ## Hydrometeorological Data Layers
# ### Compute zonal statistics

# %%
raster_metadata = {
    "Precipitation": {
        "variable": "precipitation_amount",
        "time_coord": "month",
        "unit": "mm",
        "years": range(2000, 2023),
    },
    "Temperature": {
        "variable": "t2m",
        "time_coord": "month",
        "unit": "ºC",
        "years": range(2000, 2024),
    },
    "Evapotranspiration": {
        "variable": "AETI",
        "time_coord": "months",
        "unit": "mm/day",
        "years": range(2009, 2023),
    },
    "Soil moisture": {
        "variable": "mean_swvl1_swvl2",
        "time_coord": "month",
        "unit": "%",
        "years": range(2000, 2024),
    },
}

raster_metadata = {
    "Precipitation": {
        "variable": "precipitation_amount",
        "time_coord": "month",
        "unit": "mm",
        "years": range(2000, 2023),
    },
}
dataset = raster_layers["Precipitation"]
raster_layers = {"Precipitation": dataset}

for raster_name, raster_layer in raster_layers.items():
    print("Computing zonal statistics for raster:", raster_name)
    metadata = raster_metadata[raster_name]

    for vector_name, vector_layer in vector_layers.items():
        print("  - Using vector dataset:", vector_name)
        vector_data = vector_layer.get_data()

        df_list = []
        for year in metadata["years"]:
            raster_data = raster_layer.get_data(
                temporal_coverage=slice(f"{str(year)}-01-01", f"{str(year)}-12-31")
            ).compute()

            zonal_statistics = ZonalStatisticsParallel(
                raster_data=raster_data,
                vector_data=vector_data,
                time_coord=metadata["time_coord"],
                unit=metadata["unit"],
                year=year,
            )

            df = zonal_statistics.compute()

            df_list.append(df)

        # Save the results
        df = pd.concat(df_list)
        raster_name = raster_name.replace(" ", "_")
        vector_name = (
            vector_name.lower()
            .replace(" - ", "_")
            .replace(" ", "_")
            .replace("(", "")
            .replace(")", "")
        )
        df.to_csv(f"../data/processed/ZonalStatistics/{raster_name}_{vector_name}.csv", index=False)
# Out:
# Computing zonal statistics for raster: Precipitation
#   - Using vector dataset: Administrative Boundaries - adm0
# Loading data from https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm0_4326_SouthSudan_20230829_20240228.shp...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
#   - Using vector dataset: Administrative Boundaries - adm1
# Loading data from https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm1_4326_SouthSudan_20230829_20240228.shp...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
#   - Using vector dataset: Administrative Boundaries - adm2
# Loading data from https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm2_4326_SouthSudan_20230829_20240228.shp...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
#   - Using vector dataset: Administrative Boundaries - adm3
# Loading data from https://storage.googleapis.com/wbhydross_deliverables/D3-Database/00-%20Ancillary%20Layers/OCHA-SubnationalAdministrativeBoundaries/WBHYDROSSD_OCHA_SubnationalAdministrativeBoundaries-adm3_4326_SouthSudan_20230829_20240228.shp...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
# Loading Zarr data from gs://wbhydross_deliverables/D3-Database/02- Meteorological datasets/Rainfall-CHIRPS/WBHYDROSSD_CHIRPS_5km_Precipitation_SouthSudan_1981_2022_20240425.zarr...
